# %% [markdown]
# # P2P personalized learning under different data distributions
# ---

# %% [markdown]
# ### Load libraries

# %%
import sys
sys.path.append('..')

import time
import torch
import pout
import numpy as np

from src.datasets import get_dataset
from src.models import build_models
from src.network import random_graph, network_graph
from src.helpers import Map
from src.utils import load_conf, exp_details, set_device, log
from src.plots import plot_train_history

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'  # 'svg'

# %% [markdown]
# ### Initialize configuration

# %%
torch.set_num_threads(1)
np.random.seed(0)
start_time = time.time()

# %%
args = load_conf()
args.rounds = 100
args.epochs = 3

# %%
device = set_device(args)
# Out:
# Using CPU

# %%
exp_details(args)
# Out:
# Experimental details:
#     Model     : mlp
#     Optimizer : adam
#     Learning  : 0.001
#     Rounds   : 100
#
#     Collaborative learning parameters:
#     IID
#     Number of peers    : 10
#     Local Batch size   : None
#     Epochs             : 3

# %% [markdown]
# ### Load and devide dataset

# %%
train_ds, test_ds, user_groups = get_dataset(args)

# %%
# print size of train data for each user 
[len(user_data) for user_data in user_groups.values()]
# Out:
# [6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000, 6000]

# %% [markdown]
# ### Build models

# %%
models = build_models(args)

# %%
# Model overview
models[0]
# Out:
# FFNMnist(
#   (network): Sequential(
#     (0): Linear(in_features=784, out_features=16, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=16, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### Build the network graph

# %%
# setup the network topology
topology = random_graph(models, cluster_enabled=False, k=2, sigma=-2)

# %%
# build the network graph
graph = network_graph(topology, models, train_ds, test_ds, user_groups, args)

# %% [markdown]
# ### Perform local training

# %%
train_logs = graph.local_training()
# Out:
#  Event:    Starting local training ...
#  Info:     Node(0) is performing local training ...
#            Epoch [0], val_loss: 1.8082, val_acc: 0.5900
#            Epoch [1], val_loss: 1.1005, val_acc: 0.7467
#            Epoch [2], val_loss: 0.6678, val_acc: 0.8400
#  Info:     Node(1) is performing local training ...
#            Epoch [0], val_loss: 1.7939, val_acc: 0.4617
#            Epoch [1], val_loss: 1.1429, val_acc: 0.7567
#            Epoch [2], val_loss: 0.7315, val_acc: 0.8167
#  Info:     Node(2) is performing local training ...
#            Epoch [0], val_loss: 1.6401, val_acc: 0.6217
#            Epoch [1], val_loss: 1.0010, val_acc: 0.7250
#            Epoch [2], val_loss: 0.6778, val_acc: 0.8167
#  Info:     Node(3) is performing local training ...
#            Epoch [0], val_loss: 1.6800, val_acc: 0.5250
#            Epoch [1], val_loss: 1.0475, val_acc: 0.7433
#            Epoch [2], val_loss: 0.6819, val_acc: 0.8183
#  Info:     Node(4) is performing local training ...
#            Epoch [0], val_loss: 1.9227, val_acc: 0.3333
#            Epoch [1], val_loss: 1.3760, val_acc: 0.6417
#            Epoch [2], val_loss: 0.8523, val_acc: 0.7850
#  Info:     Node(5) is performing local training ...
#            Epoch [0], val_loss: 1.7524, val_acc: 0.5783
#            Epoch [1], val_loss: 1.1063, val_acc: 0.7483
#            Epoch [2], val_loss: 0.7085, val_acc: 0.8267
#  Info:     Node(6) is performing local training ...
#            Epoch [0], val_loss: 1.9044, val_acc: 0.4683
#            Epoch [1], val_loss: 1.2854, val_acc: 0.6317
#            Epoch [2], val_loss: 0.7613, val_acc: 0.8250
#  Info:     Node(7) is performing local training ...
#            Epoch [0], val_loss: 1.7544, val_acc: 0.4333
#            Epoch [1], val_loss: 1.1120, val_acc: 0.7417
#            Epoch [2], val_loss: 0.6599, val_acc: 0.8333
#  Info:     Node(8) is performing local training ...
#            Epoch [0], val_loss: 1.7202, val_acc: 0.4533
#            Epoch [1], val_loss: 1.1115, val_acc: 0.7200
#            Epoch [2], val_loss: 0.7032, val_acc: 0.7950
#  Info:     Node(9) is performing local training ...
#            Epoch [0], val_loss: 1.7622, val_acc: 0.4483
#            Epoch [1], val_loss: 1.0538, val_acc: 0.7700
#            Epoch [2], val_loss: 0.6296, val_acc: 0.8483
#  Success:  Local training finished in 13.73 seconds.

# %%
# plot the history of local training phase
plot_train_history(train_logs, metric='accuracy', measure="mean")
plot_train_history(train_logs, metric='loss', measure="mean")

# %% [markdown]
# ### Collaborative learniing using averaging

# %%
from src.learners import average

collab_logs = graph.collaborative_training(learner=average)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#  Event:    Starting collaborative training using Average-based Collaborative Learner ...
#  Info:     Collaborative training for 100 rounds
# 100%|██████████| 100/100 [00:12<00:00,  7.99it/s, peer=Node(1), val_loss=4.11e+4, val_acc=0.145]
#  Success:  Collaborative training finished in 12.52 seconds.

# %%
# plot the history of collaborative training phase

# %% [markdown]
# ### Collaborative learniing using averaging

# %%
from src.learners import model_propagation

collab_logs = graph.collaborative_training(learner=model_propagation)
